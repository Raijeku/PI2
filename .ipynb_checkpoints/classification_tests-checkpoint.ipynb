# %%
import numpy as np
from matplotlib import pyplot as plt
import mglearn

# %%
import pandas as pd
data = pd.read_csv('datos.csv')
data
# Out:
#                 x_1           x_2  y
# 0     -1.851357e+14  3.565394e+13  0
# 1      5.715585e+14 -8.484241e+13  1
# 2      5.175931e+14 -1.231538e+14  1
# 3      5.966117e+14 -1.778714e+14  1
# 4      4.207345e+14 -1.175593e+14  1
# ...             ...           ... ..
# 16379  7.025930e+14 -1.572575e+14  0
# 16380 -8.740727e+13  7.636715e+13  0
# 16381  4.867707e+14 -1.507269e+14  1
# 16382  6.819048e+14 -1.245187e+14  1
# 16383  4.306949e+14 -2.181501e+14  1
#
# [16384 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.values[:,:2]
y = data.values[:,2]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle = False)

# %%
plt.scatter(X_train[y_train==0][:,0], X_train[y_train==0][:,1], color="blue", label="Estado 0")
plt.scatter(X_train[y_train==1][:,0], X_train[y_train==1][:,1], color="red", label="Estado 1")

# %%
from sklearn.preprocessing import RobustScaler
transformer = RobustScaler(quantile_range=(0.25,0.75)).fit(X)
X = transformer.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle = False)

# %%
plt.scatter(X_train[y_train==0][:,0], X_train[y_train==0][:,1], color="blue", label="Estado 0")
plt.scatter(X_train[y_train==1][:,0], X_train[y_train==1][:,1], color="red", label="Estado 1")

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-1.2.1-py3-none-win_amd64.whl (86.5 MB)
# Requirement already satisfied: scipy in c:\users\usuario\anaconda3\envs\quantum\lib\site-packages (from xgboost) (1.5.1)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\envs\quantum\lib\site-packages (from xgboost) (1.19.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.2.1

# %%
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

param_dist = {'objective':'binary:logistic'}
xg = xgb.XGBClassifier(**param_dist)

parameters = {'max_depth': [i for i in range(1,10)], 'eta': [0.5,1], 'n_estimators':[i for i in range(1,10)]}
clf = GridSearchCV(xg, parameters)
clf.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=False)
print(clf.best_params_)
# Out:
# {'eta': 1, 'max_depth': 6, 'n_estimators': 4}

# %%
eta = clf.best_params_['eta']
max_depth = clf.best_params_['max_depth']
n_estimators = clf.best_params_['n_estimators']
params = {'objective':param_dist['objective'], 'eta':eta, 'max_depth':max_depth, 'n_estimators':n_estimators}
clf = xgb.XGBClassifier(**params)
clf.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        verbose=False)
evals_result = clf.evals_result()
print('Score is: ',1-evals_result['validation_0']['error'][np.asarray(evals_result['validation_0']['error']).argmin()])
# Out:
# Score is:  0.953417

# %%
mglearn.plots.plot_2d_separator(clf,X_train,fill=True,alpha=.4)
mglearn.discrete_scatter(X_train[:,0],X_train[:,1],y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x1ab4596a940>,
#  <matplotlib.lines.Line2D at 0x1ab4596a670>]
