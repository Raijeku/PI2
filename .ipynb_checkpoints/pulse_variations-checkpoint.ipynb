# %%
from qiskit import QuantumCircuit, execute, Aer, IBMQ, pulse
from qiskit.tools.monitor import job_monitor
from qiskit.tools.jupyter import *
from qiskit.compiler import assemble
from qiskit.pulse import Play

provider = IBMQ.load_account()
#provider = IBMQ.get_provider(hub='ibm-q-ornl', group='ornl', project='phy141')
backend = provider.get_backend('ibmq_armonk')
backend_defaults = backend.defaults()
backend_config = backend.configuration()
assert backend_config.open_pulse, "Backend doesn't support Pulse"
calibrations = backend_defaults.instruction_schedule_map
x_schedule = calibrations.get('x',0)
# Out:
# C:\Users\usuario\AppData\Roaming\Python\Python38\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
qubit = 0

meas_map_idx = None
for i, measure_group in enumerate(backend_config.meas_map):
    if qubit in measure_group:
        meas_map_idx = i
        break
assert meas_map_idx is not None, f"Couldn't find qubit {qubit} in the meas_map!"
inst_sched_map = backend_defaults.instruction_schedule_map
measure = inst_sched_map.get('measure', qubits=backend_config.meas_map[meas_map_idx])
drive_chan = pulse.DriveChannel(qubit)
meas_chan = pulse.MeasureChannel(qubit)
acq_chan = pulse.AcquireChannel(qubit)

center_frequency_Hz = backend_defaults.qubit_freq_est[qubit] 

schedules = []

gnd_schedule = pulse.Schedule(name="ground state")
gnd_schedule += measure
schedules.append(gnd_schedule)

#initial_schedule = x_schedule
#initial_schedule += measure << initial_schedule.duration
#schedules.append(initial_schedule)

parameters = x_schedule.instructions[0][1].pulse.parameters
center_duration = parameters['duration']
durations = [center_duration + (i*16) for i in range(-30,30)]
pulses = [pulse.Drag(duration, parameters['amp'], parameters['sigma'], parameters['beta']) for duration in durations]

for current_pulse in pulses:
    current_schedule = Play(current_pulse, drive_chan)
    current_schedule += measure << current_schedule.duration
    schedules.append(current_schedule)

num_shots_per_schedule = 8192

program = assemble(schedules,
                                   backend=backend, 
                                   meas_level=1,
                                   meas_return='single',
                                   shots=num_shots_per_schedule,
                                   schedule_los=[{drive_chan: center_frequency_Hz}] * (len(durations)+1))
job = backend.run(program)
job_monitor(job)
result = job.result()
# Out:
# Job Status: job has successfully run

# %%
from matplotlib import pyplot as plt
import numpy as np
scale_factor = 0.7
gnd_results = result.get_memory(0)[:, qubit]*scale_factor
final_results = result.get_memory(31)[:, qubit]*scale_factor

final_results_list = [result.get_memory(i+1)[:, qubit]*scale_factor for i in range(len(durations))]
gnd_results_list = [gnd_results for i in range(len(durations))]


plt.figure(figsize=[4,4])
# Plot all the results
# All results from the gnd_schedule are plotted in blue
plt.scatter(np.real(gnd_results), np.imag(gnd_results), 
                s=5, cmap='viridis', c='blue', alpha=0.5, label='state_0')
# All results from the final_schedule are plotted in green
plt.scatter(np.real(final_results), np.imag(final_results), 
                s=5, cmap='viridis', c='red', alpha=0.5, label='state_1')

# Plot a large dot for the average result of the 0 and 1 states.
mean_gnd = np.mean(gnd_results) # takes mean of both real and imaginary parts
mean_final = np.mean(final_results)
plt.scatter(np.real(mean_gnd), np.imag(mean_gnd), 
            s=200, cmap='viridis', c='black',alpha=1.0, label='state_0_mean')
plt.scatter(np.real(mean_final), np.imag(mean_final), 
            s=200, cmap='viridis', c='black',alpha=1.0, label='state_2_mean')

plt.ylabel('I [a.u.]', fontsize=15)
plt.xlabel('Q [a.u.]', fontsize=15)
plt.title("0-1 discrimination", fontsize=15)
plt.show()

# %%
import pandas as pd
for i in range(len(durations)):
    df = pd.DataFrame({'x_1':gnd_results_list[i].real, 'x_2':gnd_results_list[i].imag, 'y':[0]*8192})
    final = pd.concat([df, pd.DataFrame({'x_1':final_results_list[i].real, 'x_2':final_results_list[i].imag, 'y':[1]*8192})])
    final = final.sample(frac=1)
    final.to_csv(f'datos_variaciones/datos{i}.csv', index=False)

# %%
final
# Out:
#                x_1           x_2  y
# 3378 -3.122642e+14  6.132101e+14  0
# 7138 -1.260393e+14 -3.318999e+14  0
# 5570 -3.805791e+14  4.739260e+14  0
# 3491  4.919663e+13 -2.247216e+14  1
# 7772 -4.506396e+14  4.371237e+14  1
# ...            ...           ... ..
# 4003 -2.290410e+13 -2.244483e+14  0
# 4288 -7.377585e+11 -1.691918e+14  0
# 576   2.343839e+13 -1.166913e+14  0
# 4142 -1.898507e+13 -1.144955e+14  0
# 7651  8.021283e+13 -1.773350e+14  0
#
# [16384 rows x 3 columns]
